# %%
# DATA FRAMES
# when we combine multiple series it becomes data frames.

# %%
import numpy as np
import pandas as pd

# %%
# CREATING A DATAFRAMES

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paries', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]

}
df =pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list= {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paries', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]

}
df2 =pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns = columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# SELECTION AND INDEXING OF COLUMNS

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
df2['City']
# Out:
# 0    New York
# 1      Paries
# 2      Berlin
# 3      London
# Name: City, dtype: str

# %%
df2['Salary']
# Out:
# 0    65000
# 1    70000
# 2    62000
# 3    85000
# Name: Salary, dtype: int64

# %%
df2['Age']
# Out:
# 0    28
# 1    34
# 2    29
# 3    42
# Name: Age, dtype: int64

# %%
df2[['Name', 'City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna    Paries
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2[['Salary','Age']]
# Out:
#    Salary  Age
# 0   65000   28
# 1   70000   34
# 2   62000   29
# 3   85000   42

# %%
# CREATING A NEW COLUMN

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2["Designation"] = ["Docter", "eng","doctor","eng"]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Docter
# 1   Anna   34    Paries   70000         eng
# 2  Peter   29    Berlin   62000      doctor
# 3  Linda   42    London   85000         eng

# %%
# REMOVING COLUMNS

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Docter
# 1   Anna   34    Paries   70000         eng
# 2  Peter   29    Berlin   62000      doctor
# 3  Linda   42    London   85000         eng

# %%
df2.drop('Designation',axis = 1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Docter
# 1   Anna   34    Paries   70000         eng
# 2  Peter   29    Berlin   62000      doctor
# 3  Linda   42    London   85000         eng

# %%
# to delete permentely will use inplace = 1

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Docter
# 1   Anna   34    Paries   70000         eng
# 2  Peter   29    Berlin   62000      doctor
# 3  Linda   42    London   85000         eng

# %%
df2.drop(["Designation"],axis = 1,inplace = True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# to drop rows

# %%
df2.drop(0,axis = 0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34  Paries   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# SELECTING ROWS

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34    Paries   70000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# SELECTING SUNSETS OF ROWS AND COLUMNS

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34    Paries   70000

# %%
df2.loc[[0,1]][["City", "Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1    Paries   70000

# %%
df2.loc[[0,1]][["Name", "City"]]
# Out:
#    Name      City
# 0  John  New York
# 1  Anna    Paries

# %%
df2.loc[[0,1]][["Name", "Age"]]
# Out:
#    Name  Age
# 0  John   28
# 1  Anna   34

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# CONDITIONAL SELECTIION

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# I ONLY WANT TO SEE WHOSE AGE IS ABOVE 30

# %%
df2[df2["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34  Paries   70000
# 3  Linda   42  London   85000

# %%
# I ONLY WANT WHOSE AGE IS ABOVE 30 AND THERE CITY MUST BE PARIES

# %%
df2[(df2["Age"] > 30) & (df2["City"] == 'Paries')]
# Out:
#    Name  Age    City  Salary
# 1  Anna   34  Paries   70000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34    Paries   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000
